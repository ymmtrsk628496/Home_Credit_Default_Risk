# %%
import os, sys
from typing import Any, List, Tuple
# データ処理
import numpy as np
import pandas as pd
# お絵かき
import matplotlib.pyplot as plt
import seaborn as sns
# モデル
import lightgbm as lgb
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
# 評価値
from sklearn.metrics import roc_auc_score, roc_curve, confusion_matrix, accuracy_score
# 交差検証
from sklearn.model_selection import KFold, StratifiedKFold
# ハイパーパラメターチューニング
import optuna
# ガベージコレクタ
import gc
# 正規表現
import re
# データ形成
from data_shaping import *

# %%
train, test = preprocess().get_train_test_data()
train = train.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
test = test.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
# Out:
# Data Shaping - done in 5s

# %%
def kfold_lightgbm(train_df, num_folds, stratified = False, debug= False):
    # 交差検証
    if stratified:
        folds = StratifiedKFold(n_splits= num_folds, shuffle=True, random_state=1001)
    else:
        folds = KFold(n_splits= num_folds, shuffle=True, random_state=1001)
    # 結果蓄積用DataFrame&array
    oof_preds = np.zeros(train_df.shape[0])
    feature_importance_df = pd.DataFrame()
    feats = [f for f in train_df.columns if f not in ['TARGET','SK_ID_CURR']]
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[feats], train_df['TARGET'])):
        train_x, train_y = train_df[feats].iloc[train_idx], train_df['TARGET'].iloc[train_idx]
        valid_x, valid_y = train_df[feats].iloc[valid_idx], train_df['TARGET'].iloc[valid_idx]
        # LightGBMパラメタ（要調整）
        clf = LGBMClassifier(
            num_thread=8,
            n_estimators=10000,
            learning_rate=0.02,
            num_leaves=34,
            colsample_bytree=0.95,
            subsample=0.9,
            max_depth=10,
            reg_alpha=0.04,
            reg_lambda=0.07,
            min_split_gain=0.02,
            min_child_weight=39,
            silent=-1,
            verbose=-1, )

        clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], 
            eval_metric= 'auc', verbose= 200, early_stopping_rounds= 200)

        oof_preds[valid_idx] = clf.predict_proba(valid_x, num_iteration=clf.best_iteration_)[:, 1]

        fold_importance_df = pd.DataFrame()
        fold_importance_df["feature"] = feats
        fold_importance_df["importance"] = clf.feature_importances_
        fold_importance_df["fold"] = n_fold + 1
        feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
        print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(valid_y, oof_preds[valid_idx])))
        del clf, train_x, train_y, valid_x, valid_y
        gc.collect()
    print('Full AUC score %.6f' % roc_auc_score(train_df['TARGET'], oof_preds))
    return feature_importance_df

# %%
df = train.append(test) #交差検証のため
feat_importance = kfold_lightgbm(df, num_folds= 10, stratified= True, debug= False)
# Out:
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, num_thread=8 will be ignored. Current value: num_threads=-1
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.777926	training's binary_logloss: 0.241078	valid_1's auc: 0.75401	valid_1's binary_logloss: 0.247954
# [400]	training's auc: 0.797363	training's binary_logloss: 0.23433	valid_1's auc: 0.760958	valid_1's binary_logloss: 0.245887
# [600]	training's auc: 0.811399	training's binary_logloss: 0.229599	valid_1's auc: 0.762668	valid_1's binary_logloss: 0.245382
# [800]	training's auc: 0.823289	training's binary_logloss: 0.225405	valid_1's auc: 0.763666	valid_1's binary_logloss: 0.245136
# [1000]	training's auc: 0.833782	training's binary_logloss: 0.221624	valid_1's auc: 0.764164	valid_1's binary_logloss: 0.245054
# [1200]	training's auc: 0.843145	training's binary_logloss: 0.218163	valid_1's auc: 0.763773	valid_1's binary_logloss: 0.245131
# Early stopping, best iteration is:
# [1014]	training's auc: 0.834463	training's binary_logloss: 0.221367	valid_1's auc: 0.764224	valid_1's binary_logloss: 0.245039
# Fold  1 AUC : 0.764224
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, num_thread=8 will be ignored. Current value: num_threads=-1
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.776667	training's binary_logloss: 0.241493	valid_1's auc: 0.763626	valid_1's binary_logloss: 0.245103
# [400]	training's auc: 0.795825	training's binary_logloss: 0.234824	valid_1's auc: 0.769143	valid_1's binary_logloss: 0.243127
# [600]	training's auc: 0.809995	training's binary_logloss: 0.230093	valid_1's auc: 0.77046	valid_1's binary_logloss: 0.242681
# [800]	training's auc: 0.82215	training's binary_logloss: 0.225887	valid_1's auc: 0.770839	valid_1's binary_logloss: 0.242577
# Early stopping, best iteration is:
# [718]	training's auc: 0.817372	training's binary_logloss: 0.227548	valid_1's auc: 0.771037	valid_1's binary_logloss: 0.242518
# Fold  2 AUC : 0.771037
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, num_thread=8 will be ignored. Current value: num_threads=-1
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.777678	training's binary_logloss: 0.241277	valid_1's auc: 0.758247	valid_1's binary_logloss: 0.24627
# [400]	training's auc: 0.796904	training's binary_logloss: 0.234543	valid_1's auc: 0.764765	valid_1's binary_logloss: 0.243954
# [600]	training's auc: 0.810865	training's binary_logloss: 0.229846	valid_1's auc: 0.767202	valid_1's binary_logloss: 0.243205
# [800]	training's auc: 0.822658	training's binary_logloss: 0.22576	valid_1's auc: 0.767927	valid_1's binary_logloss: 0.242999
# [1000]	training's auc: 0.833205	training's binary_logloss: 0.221958	valid_1's auc: 0.76816	valid_1's binary_logloss: 0.242953
# Early stopping, best iteration is:
# [998]	training's auc: 0.83314	training's binary_logloss: 0.221984	valid_1's auc: 0.768178	valid_1's binary_logloss: 0.24295
# Fold  3 AUC : 0.768178
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, num_thread=8 will be ignored. Current value: num_threads=-1
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.777817	training's binary_logloss: 0.241104	valid_1's auc: 0.751294	valid_1's binary_logloss: 0.24892
# [400]	training's auc: 0.797426	training's binary_logloss: 0.234294	valid_1's auc: 0.75917	valid_1's binary_logloss: 0.246587
# [600]	training's auc: 0.810986	training's binary_logloss: 0.229712	valid_1's auc: 0.761505	valid_1's binary_logloss: 0.24597
# [800]	training's auc: 0.822844	training's binary_logloss: 0.225627	valid_1's auc: 0.762582	valid_1's binary_logloss: 0.24563
# [1000]	training's auc: 0.833527	training's binary_logloss: 0.221847	valid_1's auc: 0.762428	valid_1's binary_logloss: 0.24566
# Early stopping, best iteration is:
# [866]	training's auc: 0.82645	training's binary_logloss: 0.224384	valid_1's auc: 0.762608	valid_1's binary_logloss: 0.245602
# Fold  4 AUC : 0.762608
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, num_thread=8 will be ignored. Current value: num_threads=-1
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.776829	training's binary_logloss: 0.241518	valid_1's auc: 0.765805	valid_1's binary_logloss: 0.245
# [400]	training's auc: 0.79647	training's binary_logloss: 0.234718	valid_1's auc: 0.770967	valid_1's binary_logloss: 0.242735
# [600]	training's auc: 0.81027	training's binary_logloss: 0.230132	valid_1's auc: 0.771846	valid_1's binary_logloss: 0.242322
# [800]	training's auc: 0.822602	training's binary_logloss: 0.225913	valid_1's auc: 0.772368	valid_1's binary_logloss: 0.242091
# Early stopping, best iteration is:
# [788]	training's auc: 0.82191	training's binary_logloss: 0.226157	valid_1's auc: 0.772361	valid_1's binary_logloss: 0.242087
# Fold  5 AUC : 0.772361
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, num_thread=8 will be ignored. Current value: num_threads=-1
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.776567	training's binary_logloss: 0.24153	valid_1's auc: 0.766178	valid_1's binary_logloss: 0.245067
# [400]	training's auc: 0.796006	training's binary_logloss: 0.234707	valid_1's auc: 0.772958	valid_1's binary_logloss: 0.242613
# [600]	training's auc: 0.809784	training's binary_logloss: 0.230101	valid_1's auc: 0.774708	valid_1's binary_logloss: 0.241949
# [800]	training's auc: 0.821737	training's binary_logloss: 0.225989	valid_1's auc: 0.775509	valid_1's binary_logloss: 0.241686
# [1000]	training's auc: 0.8322	training's binary_logloss: 0.222265	valid_1's auc: 0.776072	valid_1's binary_logloss: 0.241493
# [1200]	training's auc: 0.841586	training's binary_logloss: 0.218856	valid_1's auc: 0.776055	valid_1's binary_logloss: 0.241482
# Early stopping, best iteration is:
# [1088]	training's auc: 0.836501	training's binary_logloss: 0.220705	valid_1's auc: 0.776359	valid_1's binary_logloss: 0.241402
# Fold  6 AUC : 0.776359
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, num_thread=8 will be ignored. Current value: num_threads=-1
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.777431	training's binary_logloss: 0.241389	valid_1's auc: 0.758207	valid_1's binary_logloss: 0.246512
# [400]	training's auc: 0.797104	training's binary_logloss: 0.234501	valid_1's auc: 0.764173	valid_1's binary_logloss: 0.244517
# [600]	training's auc: 0.811058	training's binary_logloss: 0.229783	valid_1's auc: 0.765442	valid_1's binary_logloss: 0.244141
# [800]	training's auc: 0.822818	training's binary_logloss: 0.225664	valid_1's auc: 0.76608	valid_1's binary_logloss: 0.244021
# [1000]	training's auc: 0.833484	training's binary_logloss: 0.221849	valid_1's auc: 0.7667	valid_1's binary_logloss: 0.24391
# [1200]	training's auc: 0.843125	training's binary_logloss: 0.218238	valid_1's auc: 0.767058	valid_1's binary_logloss: 0.243852
# Early stopping, best iteration is:
# [1154]	training's auc: 0.840902	training's binary_logloss: 0.219066	valid_1's auc: 0.76723	valid_1's binary_logloss: 0.243803
# Fold  7 AUC : 0.767230
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, num_thread=8 will be ignored. Current value: num_threads=-1
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.777339	training's binary_logloss: 0.241306	valid_1's auc: 0.756346	valid_1's binary_logloss: 0.247014
# [400]	training's auc: 0.79677	training's binary_logloss: 0.234573	valid_1's auc: 0.763393	valid_1's binary_logloss: 0.244625
# [600]	training's auc: 0.810473	training's binary_logloss: 0.22994	valid_1's auc: 0.765211	valid_1's binary_logloss: 0.243936
# [800]	training's auc: 0.822402	training's binary_logloss: 0.225834	valid_1's auc: 0.766384	valid_1's binary_logloss: 0.243608
# [1000]	training's auc: 0.832942	training's binary_logloss: 0.222067	valid_1's auc: 0.766537	valid_1's binary_logloss: 0.24355
# Early stopping, best iteration is:
# [892]	training's auc: 0.827279	training's binary_logloss: 0.2241	valid_1's auc: 0.766734	valid_1's binary_logloss: 0.24347
# Fold  8 AUC : 0.766734
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, num_thread=8 will be ignored. Current value: num_threads=-1
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.777372	training's binary_logloss: 0.241387	valid_1's auc: 0.759232	valid_1's binary_logloss: 0.246303
# [400]	training's auc: 0.796768	training's binary_logloss: 0.234633	valid_1's auc: 0.766535	valid_1's binary_logloss: 0.243624
# [600]	training's auc: 0.810322	training's binary_logloss: 0.230074	valid_1's auc: 0.768196	valid_1's binary_logloss: 0.242942
# [800]	training's auc: 0.822315	training's binary_logloss: 0.225977	valid_1's auc: 0.768685	valid_1's binary_logloss: 0.242765
# [1000]	training's auc: 0.832991	training's binary_logloss: 0.222209	valid_1's auc: 0.768601	valid_1's binary_logloss: 0.242779
# Early stopping, best iteration is:
# [915]	training's auc: 0.828564	training's binary_logloss: 0.223801	valid_1's auc: 0.768788	valid_1's binary_logloss: 0.242722
# Fold  9 AUC : 0.768788
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, num_thread=8 will be ignored. Current value: num_threads=-1
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.778432	training's binary_logloss: 0.240959	valid_1's auc: 0.752154	valid_1's binary_logloss: 0.248439
# [400]	training's auc: 0.797473	training's binary_logloss: 0.23427	valid_1's auc: 0.759081	valid_1's binary_logloss: 0.246298
# [600]	training's auc: 0.811422	training's binary_logloss: 0.229551	valid_1's auc: 0.761159	valid_1's binary_logloss: 0.245662
# [800]	training's auc: 0.823199	training's binary_logloss: 0.225483	valid_1's auc: 0.761897	valid_1's binary_logloss: 0.245448
# [1000]	training's auc: 0.833701	training's binary_logloss: 0.22169	valid_1's auc: 0.762577	valid_1's binary_logloss: 0.245311
# Early stopping, best iteration is:
# [924]	training's auc: 0.829897	training's binary_logloss: 0.223072	valid_1's auc: 0.762707	valid_1's binary_logloss: 0.245252
# Fold 10 AUC : 0.762707
# Full AUC score 0.768005

# %%
# 重要度（importanceが高いほうが重要度が高い）
feat_importance.groupby("feature").mean().sort_values("importance", ascending = False).head(30)
# Out:
#                               importance  fold
# feature
# PAYMENT_RATE                      2688.8   5.5
# EXT_SOURCE_3                      1995.7   5.5
# EXT_SOURCE_1                      1664.6   5.5
# EXT_SOURCE_2                      1490.9   5.5
# DAYS_BIRTH                        1412.6   5.5
# DAYS_ID_PUBLISH                   1061.6   5.5
# DAYS_EMPLOYED                      995.8   5.5
# DAYS_EMPLOYED_PERC                 967.4   5.5
# DAYS_LAST_PHONE_CHANGE             962.0   5.5
# AMT_ANNUITY                        889.5   5.5
# AMT_GOODS_PRICE                    886.6   5.5
# DAYS_REGISTRATION                  879.5   5.5
# ANNUITY_INCOME_PERC                756.9   5.5
# AMT_CREDIT                         733.3   5.5
# REGION_POPULATION_RELATIVE         659.0   5.5
# INCOME_PER_PERSON                  558.5   5.5
# INCOME_CREDIT_PERC                 551.8   5.5
# AMT_REQ_CREDIT_BUREAU_YEAR         529.4   5.5
# OWN_CAR_AGE                        524.6   5.5
# AMT_INCOME_TOTAL                   404.6   5.5
# HOUR_APPR_PROCESS_START            369.0   5.5
# TOTALAREA_MODE                     288.7   5.5
# CODE_GENDER                        242.4   5.5
# LANDAREA_MODE                      221.1   5.5
# AMT_REQ_CREDIT_BUREAU_QRT          204.9   5.5
# BASEMENTAREA_MODE                  194.7   5.5
# LIVINGAREA_MODE                    193.7   5.5
# YEARS_BEGINEXPLUATATION_MODE       188.7   5.5
# BASEMENTAREA_AVG                   175.6   5.5
# OBS_60_CNT_SOCIAL_CIRCLE           175.4   5.5
